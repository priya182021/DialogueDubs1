# %%
! pip install git+https://github.com/openai/whisper.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 14.7 MB/s eta 0:00:00
# ...

# %%
import whisper

model = whisper.load_model("base")
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:01<00:00, 98.5MiB/s]

# %%
model.device
# Out:
# device(type='cpu')

# %%
# !git clone https://github.com/petewarden/openai-whisper-webapp
# Out:
# Cloning into 'openai-whisper-webapp'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 33 (delta 12), reused 5 (delta 1), pack-reused 0
# Receiving objects: 100% (33/33), 1.40 MiB | 11.62 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
from IPython.display import Audio
Audio("/content/drive/MyDrive/Recording.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def transcribe(audio):

    # load audio and pad/trim it to fit 30 seconds
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)

    # make log-Mel spectrogram and move to the same device as the model
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    # detect the spoken language
    _, probs = model.detect_language(mel)
    print(f"Detected language: {max(probs, key=probs.get)}")

    # decode the audio
    options = whisper.DecodingOptions(fp16 = False)
    result = whisper.decode(model, mel, options)
    return result.text

# %%
easy_text = transcribe("/content/drive/MyDrive/Recording.mp3")
print(easy_text)
# Out:
# Detected language: en
# Hi everyone, my name is Algana Rice and I have a very good application to share with you today. The name of the application is Tok Nu. And the best thing about the app is that it is going to help you connect with people who are willing to practice English with you.

# %%
easy_text
# Out:
# 'Hi everyone, my name is Algana Rice and I have a very good application to share with you today. The name of the application is Tok Nu. And the best thing about the app is that it is going to help you connect with people who are willing to practice English with you.'

# %%
edited_text = easy_text.replace("Tok Nu" , "Talk New")
edited_text = edited_text.strip()
print(edited_text)
# Out:
# Hi everyone, my name is Algana Rice and I have a very good application to share with you today. The name of the application is Talk New. And the best thing about the app is that it is going to help you connect with people who are willing to practice English with you.

# %%
# !pip install gTTS
from gtts import gTTS
text = edited_text
tts = gTTS(edited_text , lang="te")
tts.save("output.mp3")

# %%
# !pip install pydub
from pydub import AudioSegment
from pydub.playback import play

# %%
# Load the MP3 file
audio = AudioSegment.from_mp3("output.mp3")

# Play the audio
play(audio)
